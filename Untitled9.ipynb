# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.metrics import mean_squared_error

# %%
#gennerate n evenly spaced values from zero radians to 2 pi radians
n=200
x=np.linspace(0,2*np.pi,n)
sine_values=np.sin(x)

#plot tge sin wave
plt.plot(x,sine_values)

# %%
#add some noise to the sine wave
noise=0.5
noisy_sine_values=sine_values + np.random.uniform(-noise,noise,n)

#plot the noisy values
plt.plot(x,noisy_sine_values,color='r')
plt.plot(x,sine_values,linewidth=3)

# %%
#calculate the MSE using the equation
error_value=(1/n) * sum(np.power(sine_values - noisy_sine_values,2))
error_value
# Out:
# 0.0

# %%
#calculate MSE usimg the function from sklearn
#Library
mean_squared_error(sine_values,noisy_sine_values)
# Out:
# 0.08221104254391451

# %%
def error(m,x,c,t):
    N=x.size
    e=sum(((m*x+c)-t) ** 2)
    return e*1/(2*N)

# %%
#0.2 indicates 20% of  the data is randomly sampled as testing data.
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-eeeb0d64ed8d> in <module>()
#       1 #0.2 indicates 20% of  the data is randomly sampled as testing data.
#       2 from sklearn.model_selection import train_test_split
# ----> 3 xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2)
#
# NameError: name 'y' is not defined
